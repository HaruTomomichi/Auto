# %%
import pandas as pd

data_frame = pd.read_excel('./input/input1.xlsx',sheet_name='개방결과정리')
pd.set_option('display.max.colwidth', 100)
data_frame
# Out:
#     Unnamed: 0 ① 광역시도내 기관별개방현황  Unnamed: 2 Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0          NaN              순위         기관명       개방건수         NaN         NaN
# 1          NaN             NaN         NaN        NaN         NaN         NaN
# 2          NaN               1       부산광역시          5         NaN         NaN
# 3          NaN               2   부산광역시 사하구          4         NaN         NaN
# 4          NaN               3    부산광역시 서구          2         NaN         NaN
# 5          NaN               4   부산광역시 금정구          1         NaN         NaN
# 6          NaN               4    부산광역시 남구          1         NaN         NaN
# 7          NaN               4    부산광역시 동구          1         NaN         NaN
# 8          NaN               4   부산광역시 사상구          1         NaN         NaN
# 9          NaN               4   부산광역시 수영구          1         NaN         NaN
# 10         NaN               4   부산광역시 연제구          1         NaN         NaN
# 11         NaN               5   부산광역시 강서구          0         NaN         NaN
# 12         NaN               5   부산광역시 동래구          0         NaN         NaN
# 13         NaN               5  부산광역시 부산진구          0         NaN         NaN
# 14         NaN               5    부산광역시 북구          0         NaN         NaN
# 15         NaN               5   부산광역시 영도구          0         NaN         NaN
# 16         NaN               5    부산광역시 중구          0         NaN         NaN
# 17         NaN               5  부산광역시 해운대구          0         NaN         NaN
# 18         NaN               5   부산광역시 기장군          0         NaN         NaN
#
#     Unnamed: 6 Unnamed: 7      ② 개방데이터 요약               Unnamed: 9  \
# 0          NaN         구분             NaN                      NaN
# 1          NaN        NaN             NaN                      NaN
# 2          NaN   개방데이터목록수             NaN                      NaN
# 3          NaN        일관성              채널  공공데이터포털(data.go.kr)등록건수
# 4          NaN        NaN             NaN         공공데이터포털외에만등록한 건수
# 5          NaN        활용성              유형                     오픈포맷
# 6          NaN        NaN             NaN                   非 오픈포맷
# 7          NaN       개방활동              등록                    2020년
# 8          NaN        NaN             NaN                    2019년
# 9          NaN        NaN             NaN                    2018년
# 10         NaN        NaN             NaN                 2018년 이전
# 11         NaN       개방수요  다운\n로드\n(Top7)                       총수
# 12         NaN        NaN             NaN          1위 개방데이터명\n(횟수)
# 13         NaN        NaN             NaN          2위 개방데이터명\n(횟수)
# 14         NaN        NaN             NaN          3위 개방데이터명\n(횟수)
# 15         NaN        NaN             NaN          4위 개방데이터명\n(횟수)
# 16         NaN        NaN             NaN          5위 개방데이터명\n(횟수)
# 17         NaN        NaN             NaN          6위 개방데이터명\n(횟수)
# 18         NaN        NaN             NaN          7위 개방데이터명\n(횟수)
#
#     Unnamed: 10 Unnamed: 11                 Unnamed: 12  \
# 0           NaN          단위                        소속기관
# 1           NaN         NaN                         NaN
# 2           NaN           件                           1
# 3           NaN           件                           1
# 4           NaN           件                           0
# 5           NaN           件                           1
# 6           NaN           件                           0
# 7           NaN           件                           1
# 8           NaN           件                           0
# 9           NaN           件                           0
# 10          NaN           件                           0
# 11          NaN           件                          14
# 12          NaN           名  부산광역시 남구_액화석유가스판매업소현황 (14)
# 13          NaN           名                         NaN
# 14          NaN           名                         NaN
# 15          NaN           名                         NaN
# 16          NaN           名                         NaN
# 17          NaN           名                         NaN
# 18          NaN           名                         NaN
#
#                                       광역기관수         17  \
# 0                                      광역시도        NaN
# 1                                         총         평균
# 2                                        17          1
# 3                                        17          1
# 4                                       NaN        NaN
# 5                                        15   0.882353
# 6                                         2   0.117647
# 7                                        16   0.941176
# 8                                         1  0.0588235
# 9                                         0          0
# 10                                        0          0
# 11                                      436        NaN
# 12                     부산광역시_수출지원사업 정보 (55)        NaN
# 13  부산광역시_빅데이터플랫폼_국세청100대업소현황_20180601 (42)        NaN
# 14                 부산광역시 금정구_대부업 등록 현황 (36)        NaN
# 15                  부산광역시_수영구_국공유재산 현황 (35)        NaN
# 16             부산광역시_서구_계약정보시스템\n접속 현황 (33)        NaN
# 17     부산광역시_사하구_계약정보공개\n시스템 홈페이지 공지사항 (33)        NaN
# 18       부산광역시_사하구_계약정보공개시스템 홈페이지 방문횟수 (33)        NaN
#
#                                             Unnamed: 15
# 0                                                    비고
# 1                                                   NaN
# 2                                 부산광역시_남구_액화석유가스판매업소현황
# 3                                 부산광역시_남구_액화석유가스판매업소현황
# 4                         부산공공데이터포털 자료는\n공공데이터포털 자료와 동일
# 5                                               15(CSV)
# 6                                           2(LINK-XLS)
# 7                                 2019.10.01~2020.09.30
# 8   2018.10.01~2019.09.30 (부산광역시_수출지원사업 정보(2019.08.30))
# 9                                 2017.10.01~2018.09.30
# 10                                          ~2017.09.30
# 11                                 17개 자료 436회 Download
# 12                                                  NaN
# 13                                                  NaN
# 14                  부산광역시 금정구_대부업 등록 현황_20200522 파일과 동일
# 15                                                  NaN
# 16                            5,6,7위는 다운로드 횟수가 33회로 동일함
# 17                            5,6,7위는 다운로드 횟수가 33회로 동일함
# 18                            5,6,7위는 다운로드 횟수가 33회로 동일함

# %%
data_frame.head()
# Out:
#    Unnamed: 0 ① 광역시도내 기관별개방현황 Unnamed: 2 Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0         NaN              순위        기관명       개방건수         NaN         NaN
# 1         NaN             NaN        NaN        NaN         NaN         NaN
# 2         NaN               1      부산광역시          5         NaN         NaN
# 3         NaN               2  부산광역시 사하구          4         NaN         NaN
# 4         NaN               3   부산광역시 서구          2         NaN         NaN
#
#    Unnamed: 6 Unnamed: 7 ② 개방데이터 요약               Unnamed: 9  Unnamed: 10  \
# 0         NaN         구분        NaN                      NaN          NaN
# 1         NaN        NaN        NaN                      NaN          NaN
# 2         NaN   개방데이터목록수        NaN                      NaN          NaN
# 3         NaN        일관성         채널  공공데이터포털(data.go.kr)등록건수          NaN
# 4         NaN        NaN        NaN         공공데이터포털외에만등록한 건수          NaN
#
#   Unnamed: 11 Unnamed: 12 광역기관수   17                    Unnamed: 15
# 0          단위        소속기관  광역시도  NaN                             비고
# 1         NaN         NaN     총   평균                            NaN
# 2           件           1    17    1          부산광역시_남구_액화석유가스판매업소현황
# 3           件           1    17    1          부산광역시_남구_액화석유가스판매업소현황
# 4           件           0   NaN  NaN  부산공공데이터포털 자료는\n공공데이터포털 자료와 동일

# %%
data_frame[['Unnamed: 2','Unnamed: 3']]
# Out:
#     Unnamed: 2 Unnamed: 3
# 0          기관명       개방건수
# 1          NaN        NaN
# 2        부산광역시          5
# 3    부산광역시 사하구          4
# 4     부산광역시 서구          2
# 5    부산광역시 금정구          1
# 6     부산광역시 남구          1
# 7     부산광역시 동구          1
# 8    부산광역시 사상구          1
# 9    부산광역시 수영구          1
# 10   부산광역시 연제구          1
# 11   부산광역시 강서구          0
# 12   부산광역시 동래구          0
# 13  부산광역시 부산진구          0
# 14    부산광역시 북구          0
# 15   부산광역시 영도구          0
# 16    부산광역시 중구          0
# 17  부산광역시 해운대구          0
# 18   부산광역시 기장군          0

# %%
data_frame[['① 광역시도내 기관별개방현황','Unnamed: 2','Unnamed: 3']][2:7]
# Out:
#   ① 광역시도내 기관별개방현황 Unnamed: 2 Unnamed: 3
# 2               1      부산광역시          5
# 3               2  부산광역시 사하구          4
# 4               3   부산광역시 서구          2
# 5               4  부산광역시 금정구          1
# 6               4   부산광역시 남구          1

# %%
name_ls, amount_ls = [],[]

for i in range(2,7):
    name_ls.append(str(data_frame['① 광역시도내 기관별개방현황'][i]) + '등(' + data_frame['Unnamed: 2'][i] + ')')    
    amount_ls.append(data_frame['Unnamed: 3'][i])
    
print(name_ls)
# Out:
# ['1등(부산광역시)', '2등(부산광역시 사하구)', '3등(부산광역시 서구)', '4등(부산광역시 금정구)', '4등(부산광역시 남구)']

# %%
import matplotlib.pyplot as plt

plt.plot(name_ls,amount_ls,'rs--')
plt.rcParams["figure.figsize"] = (10,4)
plt.rc('font',family = 'NanumGothic')
plt.grid(True)

for i, v in enumerate(name_ls):
    plt.text(v, amount_ls[i], amount_ls[i],                 # 좌표 (x축 = v, y축 = y[0]..y[1], 표시 = y[0]..y[1])
             fontsize = 15, 
             color='black',
             horizontalalignment='center',  # horizontalalignment (left, center, right)
             verticalalignment='bottom')    # verticalalignment (top, center, bottom)

print(plt.rcParams['font.family'])
# Out:
# ['NanumGothic']

# %%
data_frame = data_frame[['① 광역시도내 기관별개방현황','Unnamed: 2','Unnamed: 3']][2:7]
data_frame.to_excel('temp_result.xlsx', index=False)

# %%
data_frame = pd.read_excel('./temp_result.xlsx')
data_frame
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-24-6708aab62af1> in <module>
# ----> 1 data_frame = pd.read_excel('./temp_result.xlsx')
#       2 data_frame
#
# ~\anaconda3\envs\prac\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# ~\anaconda3\envs\prac\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols)
#     302
#     303     if not isinstance(io, ExcelFile):
# --> 304         io = ExcelFile(io, engine=engine)
#     305     elif engine and engine != io.engine:
#     306         raise ValueError(
#
# ~\anaconda3\envs\prac\lib\site-packages\pandas\io\excel\_base.py in __init__(self, path_or_buffer, engine)
#     865         self._io = stringify_path(path_or_buffer)
#     866
# --> 867         self._reader = self._engines[engine](self._io)
#     868
#     869     def __fspath__(self):
#
# ~\anaconda3\envs\prac\lib\site-packages\pandas\io\excel\_xlrd.py in __init__(self, filepath_or_buffer)
#      20         err_msg = "Install xlrd >= 1.0.0 for Excel support"
#      21         import_optional_dependency("xlrd", extra=err_msg)
# ---> 22         super().__init__(filepath_or_buffer)
#      23
#      24     @property
#
# ~\anaconda3\envs\prac\lib\site-packages\pandas\io\excel\_base.py in __init__(self, filepath_or_buffer)
#     351             self.book = self.load_workbook(filepath_or_buffer)
#     352         elif isinstance(filepath_or_buffer, str):
# --> 353             self.book = self.load_workbook(filepath_or_buffer)
#     354         elif isinstance(filepath_or_buffer, bytes):
#     355             self.book = self.load_workbook(BytesIO(filepath_or_buffer))
#
# ~\anaconda3\envs\prac\lib\site-packages\pandas\io\excel\_xlrd.py in load_workbook(self, filepath_or_buffer)
#      35             return open_workbook(file_contents=data)
#      36         else:
# ---> 37             return open_workbook(filepath_or_buffer)
#      38
#      39     @property
#
# ~\anaconda3\envs\prac\lib\site-packages\xlrd\__init__.py in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#     109     else:
#     110         filename = os.path.expanduser(filename)
# --> 111         with open(filename, "rb") as f:
#     112             peek = f.read(peeksz)
#     113     if peek == b"PK\x03\x04": # a ZIP file
#
# FileNotFoundError: [Errno 2] No such file or directory: './temp_result.xlsx'

# %%
import pandas as pd
import matplotlib.pyplot as plt

num = int(input('현재 데이터의 갯수가 몇개입니까? : '))
final_df = pd.DataFrame() # 데이터 프레임을 사용할 것이라는 명시만 한다
graph_seq = str(num) + '11' # 그래프의 순서 번호 / 2행 1열 1번째라고 읽으면 됨

for i in range(num):
    # 여기서는 데이터를 처리하는 구간입니다
    data_frame = pd.read_excel('./input/input' + str(i+1) + '.xlsx', sheet_name='개방결과정리') # 엑셀 파일 불러오기
    data_frame = data_frame[['① 광역시도내 기관별개방현황','Unnamed: 2','Unnamed: 3']][2:7] # top5 랭킹 데이터만 가져오기
    data_frame.columns = ['Ranking', 'Name', 'Quantity'] # 속성명이 이상하게 되어있으므로 다시 잡아주기

    # 여기서는 subplot 그래프의 데이터를 처리하는 구간입니다
    name_ls, amount_ls = [],[]
    for j in range(2, 7):
        name_ls.append(str(data_frame['Ranking'][j]) + '등(' + data_frame['Name'][j] + ')')
        amount_ls.append(data_frame['Quantity'][j])

    # 여기서는 그래프를 그리는 구간입니다
    plt.subplot(int(graph_seq))
    plt.rcParams["figure.figsize"] = (10, 5)
    plt.plot(name_ls, amount_ls, 'rs--')
    plt.rc('font', family='NanumGothic')
    plt.grid()

    for j, v in enumerate(name_ls):
        plt.text(v, amount_ls[j], amount_ls[j],  # 좌표 (x축 = v, y축 = y[0]..y[1], 표시 = y[0]..y[1])
                 fontsize=15,
                 color='black',
                 horizontalalignment='center',  # horizontalalignment (left, center, right)
                 verticalalignment='bottom')

    graph_seq = graph_seq[:2] + str(i + 2)  # 다음 그래프의 순서 번호를 지정

    data_frame = data_frame.append({'Ranking': '', 'Name': '', 'Quantity': ''}, ignore_index=True)  # 한칸 띄워주기
    final_df = pd.concat([final_df,data_frame])

# 세부 그래프간의 간격을 조정
plt.subplots_adjust(left=0.125,
                    bottom=0.1,
                    right=0.9,
                    top=0.9,
                    wspace=0.2,
                    hspace=0.35)

final_df.to_excel('result.xlsx',index = False)
plt.show()
# Out:
# 현재 데이터의 갯수가 몇개입니까? : 3
